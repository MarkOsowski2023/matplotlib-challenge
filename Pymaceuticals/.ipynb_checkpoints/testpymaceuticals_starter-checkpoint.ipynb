# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

print(mouse_metadata.head())
print(study_results.head())

# Combine the data into a single dataset
df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
# Display the data table for preview
df
df.columns
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# USE PRINT THE NUMBER OF MICE USING THE LEN FUNCTION AND UNIQUE METHOD
df["Mouse ID"].unique()
print(len(df["Mouse ID"].unique()))
# Out:
# 249

# %%
# TRIAL AND ERROR
indexed_df = df.set_index(["Mouse ID", "Timepoint"])
indexed_df.duplicated()
XcleanX_df = indexed_df.drop_duplicates()
XcleanX_df.count
# Out:
# <bound method DataFrame.count of                    Drug Regimen   Sex  Age_months  Weight (g)  \
# Mouse ID Timepoint
# k403     0             Ramicane  Male          21          16
#          5             Ramicane  Male          21          16
#          10            Ramicane  Male          21          16
#          15            Ramicane  Male          21          16
#          20            Ramicane  Male          21          16
# ...                         ...   ...         ...         ...
# z969     25            Naftisol  Male           9          30
#          30            Naftisol  Male           9          30
#          35            Naftisol  Male           9          30
#          40            Naftisol  Male           9          30
#          45            Naftisol  Male           9          30
#
#                     Tumor Volume (mm3)  Metastatic Sites
# Mouse ID Timepoint
# k403     0                   45.000000                 0
# ...

# %%
# TRIAL AND ERROR
XcleanX_df.index.duplicated()
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# TRIAL AND ERROR
XcleanX_df.index
# Out:
# MultiIndex([('k403',  0),
#             ('k403',  5),
#             ('k403', 10),
#             ('k403', 15),
#             ('k403', 20),
#             ('k403', 25),
#             ('k403', 30),
#             ('k403', 35),
#             ('k403', 40),
#             ('k403', 45),
#             ...
#             ('z969',  0),
#             ('z969',  5),
#             ('z969', 10),
#             ('z969', 15),
#             ('z969', 20),
#             ('z969', 25),
#             ('z969', 30),
#             ('z969', 35),
#             ('z969', 40),
#             ('z969', 45)],
#            names=['Mouse ID', 'Timepoint'], length=1885)

# %%
# Getting the duplicate entries by mouse ID number that show up for Mouse ID and Timepoint.

# ON THE RIGHT TRACK
indexdf2 = df.set_index(["Mouse ID"])
timpoint_duplicates = indexdf2["Timepoint"].duplicated()
duplicate_rows = indexdf2[timpoint_duplicates]
duplicate_check = indexdf2[indexdf2.duplicated(["Timepoint"])]
duplicate_check
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# s185        Capomulin  Female           3          17          0
# s185        Capomulin  Female           3          17          5
# s185        Capomulin  Female           3          17         10
# s185        Capomulin  Female           3          17         15
# s185        Capomulin  Female           3          17         20
# ...               ...     ...         ...         ...        ...
# z969         Naftisol    Male           9          30         25
# z969         Naftisol    Male           9          30         30
# z969         Naftisol    Male           9          30         35
# z969         Naftisol    Male           9          30         40
# z969         Naftisol    Male           9          30         45
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# s185               45.000000                 0
# s185               43.878496                 0
# ...

# %%
# WORKS USE
dups = df[df.duplicated(["Mouse ID", "Timepoint"])]
dups
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# WORKS USE
clean_df = df.drop_duplicates(subset=["Mouse ID", "Timepoint"], keep='last')
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 

clean_df.columns
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# %%
# Checking the number of mice in the clean DataFrame.
# WORKS USE
print(len(clean_df["Mouse ID"].unique()))
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# ACTUALLY using goupby and aggregations with numpy and scipy stats
summary_tumor = copy2_clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg([np.mean, np.median, np.var, np.std, st.sem])
summary_tumor
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.382993  50.783528  43.220205  6.574208  0.526358
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# took way too long
print(clean_df["Drug Regimen"].unique())
ramicane  = copy2_clean_df.loc[copy2_clean_df["Drug Regimen"] == "Ramicane"]
ramicane_group = ramicane.groupby(["Drug Regimen"])
capomulin = copy2_clean_df.loc[copy2_clean_df["Drug Regimen"] == "Capomulin"]
capomulin_group = capomulin.groupby(["Drug Regimen"])
infubinol = copy2_clean_df.loc[copy2_clean_df["Drug Regimen"] == "Infubinol"]
infubinol_group = infubinol.groupby(["Drug Regimen"])
placebo = copy2_clean_df
# Out:
# ['Ramicane' 'Capomulin' 'Infubinol' 'Placebo' 'Ceftamin' 'Stelasyn'
#  'Zoniferol' 'Ketapril' 'Propriva' 'Naftisol']

# %%
# took way too long
# Make copy of clean df
copy1 = clean_df.copy()

# using loc and group by to make data frame with the copy of clean df
print(copy1["Drug Regimen"].unique())
# Ramicane
ramicane = copy1.loc[copy1["Drug Regimen"] == "Ramicane"]
ramicane_group = ramicane.groupby(["Drug Regimen"])

# Capomulin
capolumin = copy1.loc[copy1["Drug Regimen"] == "Capomulin"]
capolumin_group = capolumin.groupby(["Drug Regimen"])

# Infubinol
infubinol = copy1.loc[copy1["Drug Regimen"] == "Infubinol"]
infubinol_group = infubinol.groupby(["Drug Regimen"])

# Placebo
placebo = copy1.loc[copy1["Drug Regimen"] == "Placebo"]
placebo_group = placebo.groupby(["Drug Regimen"])

# Ceftamin
ceftamin = copy1.loc[copy1["Drug Regimen"] == "Ceftamin"]
ceftamin_group = ceftamin.groupby(["Drug Regimen"])

# Stelasyn
stelasyn = copy1.loc[copy1["Drug Regimen"] == "Ceftamin"]
stelasyn_group = stelasyn.groupby(["Drug Regimen"])

# Zoniferol
zoniferol = copy1.loc[copy1["Drug Regimen"] == "Zoniferol"]
zoniferol_group = zoniferol.groupby(["Drug Regimen"])

# Ketapril
ketapril = copy1.loc[copy1["Drug Regimen"] == "Ketapril"]
ketapril_group = ketapril.groupby(["Drug Regimen"])

# Propriva 
propriva = copy1.loc[copy1["Drug Regimen"] == "Propriva"]
propriva_group = propriva.groupby(["Drug Regimen"])

# Naftisol
naftisol = copy1.loc[copy1["Drug Regimen"] == "Naftisol"]
naftisol_group = naftisol.groupby(["Drug Regimen"])

# Making a reduced data frame using the copy
reduced_df = copy1[["Drug Regimen", "Tumor Volume (mm3)"]]

# %%
# USE FOR GROUPBY METHOD
# making a reduced data frame
copy2_clean_df = clean_df.copy()
reduced_df = copy2_clean_df[["Mouse ID", "Drug Regimen", "Tumor Volume (mm3)"]]
reduced_df
reg_group = reduced_df.groupby(["Drug Regimen"])
mean_regimen_tumor_volume = reg_group.mean()
median_regimen_tumor_volume = reg_group.median()
variance_regimen_tumor_volume = reg_group.var()
standard_deviation_regimine_tumor = reg_group.std()
sem_regimen_tumor_volume = reg_group.sem()

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Setting Variable for Tumor Volume
tumor_volume = clean_df["Tumor Volume (mm3)"]

# setting variable and calculating values for tumor volume using numpy.mean, median, var, and std
mean_tumor_volume = np.mean(tumor_volume)

median_tumor_volume = np.median(tumor_volume)

variance_tumor_volume = np.var(tumor_volume,ddof=0)

standard_dev_tumor_volume = np.std(tumor_volume,ddof=0)

# adding these to columns
# making copy of clean data set
copy1_clean_df = clean_df.copy



print(f"Mean is {mean_tumor_volume}")
print(f"Median is {median_tumor_volume}")
print(f"Variance is {variance_tumor_volume}")
print(f"Standard Deviation is {standard_dev_tumor_volume}")

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
regimen_groups = clean_df.groupby(["Drug Regimen"])
regimen_groups["Tumor Volume(mm3)"].mean()
# Out:
# Mean is 50.4484113365678
# Median is 48.951421075
# Variance is 79.25260719229753
# Standard Deviation is 8.902393340686398
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16108\1275421612.py in <module>
#      29 # Assemble the resulting series into a single summary dataframe.
#      30 regimen_groups = clean_df.groupby(["Drug Regimen"])
# ---> 31 regimen_groups["Tumor Volume(mm3)"].mean()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1601                 stacklevel=2,
#    1602             )
# -> 1603         return super().__getitem__(key)
#    1604
#    1605     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     228         else:
#     229             if key not in self.obj:
# ...

# %%
summary_tumor = pd.DataFrame([{"Regimen": clean_df["Drug Regimen"],
                              "Mean Tumor Voluem": mean_tumor_volume,
                              "Median Tumor Volume": median_tumor_volume,
                              "Variance Tumor Volume": variance_tumor_volume,
                              "Standar Deviation of Tumor Volume": standard_dev_tumor_volume}])
summary_tumor
# Out:
#                                              Regimen  Mean Tumor Voluem  \
# 0  [[Ramicane, Ramicane, Ramicane, Ramicane, Rami...          50.448411
#
#    Median Tumor Volume  Variance Tumor Volume  \
# 0            48.951421              79.252607
#
#    Standar Deviation of Tumor Volume
# 0                           8.902393

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# Make copy of clean df
copy1 = clean_df.copy()

# Drug Regimen values
print(copy1["Drug Regimen"].unique())


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.

# Using groupby method with numpy and scipy stats to calculate
reg_group = copy1.groupby(["Drug Regimen"])
mean_regimen_tumor_volume = reg_group['Tumor Volume (mm3)'].mean()
median_regimen_tumor_volume = reg_group['Tumor Volume (mm3)'].median()
variance_regimen_tumor_volume = reg_group['Tumor Volume (mm3)'].var()
standard_deviation_regimen_tumor = reg_group['Tumor Volume (mm3)'].std()
sem_regimen_tumor_volume = reg_group['Tumor Volume (mm3)'].sem()

# print(mean_regimen_tumor_volume)
# print(median_regimen_tumor_volume)
# print(variance_regimen_tumor_volume)
# print(standard_deviation_regimen_tumor)
# print(sem_regimen_tumor_volume)

# Assemble the resulting series into a single summary dataframe.
summary_groups = pd.DataFrame({"Mean": mean_regimen_tumor_volume,
                              "Median": median_regimen_tumor_volume,
                              "Variance": variance_regimen_tumor_volume,
                              "Standard Deviation": standard_deviation_regimen_tumor,
                              "Sem": sem_regimen_tumor_volume})
summary_groups
# Out:
# ['Ramicane' 'Capomulin' 'Infubinol' 'Placebo' 'Ceftamin' 'Stelasyn'
#  'Zoniferol' 'Ketapril' 'Propriva' 'Naftisol']
#                    Mean     Median   Variance  Standard Deviation       Sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.382993  50.783528  43.220205            6.574208  0.526358
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
drug_regimen_summary_table = copy1.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg([np.mean, np.median, np.var, np.std, st.sem])

drug_regimen_summary_table
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.382993  50.783528  43.220205  6.574208  0.526358
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# on the right track
group1 = new_df.groupby(['Drug Regimen', 'Mouse ID']).sum()
group1
# Out:
#                        Timepoint
# Drug Regimen Mouse ID
# Capomulin    b128            225
#              b742            225
#              f966             50
#              g288            225
#              g316            225
# ...                          ...
# Zoniferol    q633            225
#              s337            225
#              w140              5
#              w575            225
#              x613             30
#
# [249 rows x 1 columns]

# %%
chart1 = group1.plot(kind='bar', figsize=(40,20))

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
# plot method
print(clean_df.columns)
new_df = clean_df[['Mouse ID', 'Drug Regimen', 'Timepoint']]
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for a for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. timepoint for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
